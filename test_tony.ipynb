# %%
import sys , os 
import numpy as np
import math as m
import pandas as pd

import plotly.offline as py

import plotly.graph_objs as go
py.offline.init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
energy='9'
heter='l'
depth='20'
mesurePlot="/home/crct/CRCT/JupyterNotebook/data/gammaIndex/"+energy+"E/new/f"+heter+energy+"e"+depth+".csv"
gatePlot="/home/crct/CRCT/JupyterNotebook/data/gammaIndex/"+energy+"E/new/g"+heter+energy+"e"+depth+".csv"
#gatePlotw="/home/crct/CRCT/JupyterNotebook/data/gammaIndex/"+energy+"E/new/g"+heter+energy+"e"+depth+"w.csv"
emcPlot="/home/crct/CRCT/JupyterNotebook/data/gammaIndex/"+energy+"E/new/emc"+heter+energy+"e"+depth+".csv"
#emcPlot="/home/crct/CRCT/JupyterNotebook/gammaIndex/"+energy+"E/new/emcTEST.csv"
gateuncertaityPlot="/home/crct/CRCT/JupyterNotebook/data/gammaIndex/"+energy+"E/new/uncertainty/"+heter+"g"+energy+"e"+depth+"_uncertainty.csv"
#gateuncertaityPlot="/home/crct/CRCT/JupyterNotebook/gammaIndex/"+energy+"E/new/uncertainty/gb6e20_uncertaintyAbs.csv"
#gateuncertaityPlotw="/home/crct/CRCT/JupyterNotebook/data/gammaIndex/"+energy+"E/new/uncertainty/g"+heter+energy+"e"+depth+"w_uncertainty.csv"

mesurePlotData=pd.read_csv(mesurePlot, sep=',')
gatePlotData=pd.read_csv(gatePlot, sep=',')
#gatePlotDataw=pd.read_csv(gatePlotw, sep=',')
emcPlotData=pd.read_csv(emcPlot, sep=',')

gateuncertaintyPlotData=pd.read_csv(gateuncertaityPlot, sep=',')
#gateuncertaintyPlotDataw=pd.read_csv(gateuncertaityPlot, sep=',')

# %%
LinearInterpolation=True
#Point every (in mm)
#NewStep=0.1

Threshold=True
#Of Dmax
ThresholdValue=0.1

#Gamma Index criterion 
DTA=3 #mm
deltaDmax=0.03 #%


name='stair6e30_good'

# %%
xGscale=8
xGscalew=0
xEMCscale=8

mdown=-15
mup=-10


#Create numpy ndarray from pandas dataFrames
refX=mesurePlotData['pas']
refY=mesurePlotData['value']
gateX=gatePlotData['pas']
gateY=gatePlotData['value']
emcX=emcPlotData['pas']
emcY=emcPlotData['value']
#gateXw=gatePlotDataw['pas']
#gateYw=gatePlotDataw['value']

gateUx=gateuncertaintyPlotData['pas']
gateUy=gateuncertaintyPlotData['value']

#gateUxw=gateuncertaintyPlotDataw['pas']
#gateUyw=gateuncertaintyPlotDataw['value']
print(gateUy[50])
refX=refX-(refX.max()/2)
emcX=emcX-(emcX.max()/2)

#Dose Grid scaing
#emcY=(emcY*4.0e-6)/2
refY=refY*0.01
#gateUy=gateUy*100

# Compute Linear interpolation for simulated values and measured values according to your parameters (change 1000 values to change number of points)
if LinearInterpolation==True:
    refX2=np.linspace(refX.min(), refX.max(), 2000)
    refY2=np.interp(refX2, refX, refY)
    gateX2=np.linspace(gateX.min(), gateX.max(), 2000)
    gateY2=np.interp(gateX2, gateX, gateY)
    emcX2=np.linspace(emcX.min(), emcX.max(), 2000)
    emcY2=np.interp(emcX2, emcX, emcY)

    gateUx2=np.linspace(gateUx.min(), gateX.max(), 2000)
    gateUy2=np.interp(gateUx2, gateUx, gateUy)
else:
    refX2= refX
    refY2= refY
    gateX2= gateX
    gateY2= gateY
    emcX2= emcX
    emcY2= emcY
emcX2=np.flipud(emcX2)
#gateUy2=gateUy2*100
#gateUy2=gateUy2*100
print(gateUy[0])
#print(gateUy2[50])
maskFilm=(refX2 > mdown) & (refX2 < mup)
maskGate=(gateX2 > mdown) & (gateX2 < mup)
maskEmc=(emcX2 > mdown) & (emcX2 < mup)

a=refY2[maskFilm].mean()
b=emcY2[maskEmc].mean()
n=b/a


a1=gateY2[maskGate].mean()
b1=emcY2[maskEmc].mean()
n1=b1/a1


#refY2=refY2*n
#gateY2=gateY2*n1
#gateY2w=gateY2w*n1
#gateUy2=gateUy2*gateY2
#normalisation mean homogeneity
refY2=refY2/refY2[maskFilm].mean()
gateY2=gateY2/gateY2[maskGate].mean()
emcY2=emcY2/emcY2[maskEmc].mean()


#uncertainies

gateUy2=gateUy2*gateY2
#print(gateUy2[50])
#gateUy2=gateUy2*100
#gateUy2=gateUy2*gateY2
print(gateUy2[0])
    #SCALING
gateX2=gateX2+xGscale
emcX2=emcX2+xEMCscale

print 'ok'
# Out:
# 0.00969994626939
# 0.121641874313
# 0.000799580598349
# ok

# %%
#  GATE  #

#create numpy ndarray for gamma comprison
deltaD=np.zeros(len(refY2))
gammaIndex=np.zeros(len(gateX2))
gammaIndexTEMP=np.zeros(len(refX2))
drTEMP=np.zeros(len(refX2))
dr=np.zeros(len(refX2))

#compute Gamma Index 1D
for i in range(len(gateX2)):
    for j in range(len(refX2)):
        dr[j]=(gateX2[i]-refX2[j])
        deltaD[j]=gateY2[i]-refY2[j]
        gammaIndexTEMP[j]=m.sqrt(((deltaD[j]**2)/deltaDmax**2) + ((dr[j]**2)/DTA**2))           
    gammaIndex[i]=gammaIndexTEMP.min()

#Compute Gamma Index Pass Rate (with threshold or not)
nok=0.0
a=0
if Threshold==True: 
    for i in range(len(gammaIndex)):

        if gateY2[i]>0.10:
            a=a+1
            if gammaIndex[i]<1:
                nok=nok+1
    print ('nombre de points testés : ' +str(a))
    print ('nombre de points passant le test (<1) : ' +str(nok))
    passRate=(nok/a)*100
else:
    nok=(gammaIndex < 1).sum()
    passRate=nok*100.0/len(gammaIndex)

#print results
percentDmax=deltaDmax*100
print('RESULTAT GATE : ')
print('*   Gamma Index Pass Rate '+str(percentDmax) + '%-' +str(DTA) + 'mm: '  +str(passRate) +' %')
# Out:
# nombre de points testés : 1203
# nombre de points passant le test (<1) : 1120.0
# RESULTAT GATE :
# *   Gamma Index Pass Rate 3.0%-3mm: 93.1005818786 %

# %%
#    EMC   #

#create numpy ndarray for gamma comprison
deltaD=np.zeros(len(refY2))
gammaIndex2=np.zeros(len(emcX2))
gammaIndexTEMP=np.zeros(len(refX2))
drTEMP=np.zeros(len(refX2))
dr=np.zeros(len(refX2))

#compute Gamma Index 1D
for i in range(len(emcX2)):
    for j in range(len(refX2)):
        dr[j]=(emcX2[i]-refX2[j])
        deltaD[j]=emcY2[i]-refY2[j]
        gammaIndexTEMP[j]=m.sqrt(((deltaD[j]**2)/deltaDmax**2) + ((dr[j]**2)/DTA**2))
    #print gammaIndexTEMP.argmin()
    gammaIndex2[i]=gammaIndexTEMP.min()
#print gammaIndex2
#Compute Gamma Index Pass Rate (with threshold or not)
nok=0.0
a=0
if Threshold==True: 
    for i in range(len(gammaIndex2)):

        if emcY2[i]>0.10:
            a=a+1
            if gammaIndex2[i]<1:
                nok=nok+1
    print ('nombre de points testés : ' +str(a))
    print ('nombre de points passant le test (<1) : ' +str(nok))
    passRate2=(nok/a)*100
else:
    nok=(gammaIndex2 < 1).sum()
    passRate2=nok*100.0/len(gammaIndex2)

#print results
percentDmax=deltaDmax*100
print('RESULTAT EMC : ')
print('*   Gamma Index Pass Rate '+str(percentDmax) + '% - ' +str(DTA) + 'mm : '  +str(passRate2) +' %')
# Out:
# nombre de points testés : 826
# nombre de points passant le test (<1) : 597.0
# RESULTAT EMC :
# *   Gamma Index Pass Rate 3.0% - 3mm : 72.2760290557 %

# %%
# Plot profil or PDD with plotly      
trace1 = go.Scatter(
    x = refX2,
    y = refY2,
    mode = 'lines', 
    name = 'Film Measure', 
    
    line = dict(
        color = ('rgba(214, 39, 40, 100)')
    )
)

trace2 = go.Scatter(
    x = gateX2,
    y = gateY2,
    mode = 'lines', 
    name = 'GATE', 
    line = dict(
        color = ('rgba(44, 160, 44, 100)'),
        dash='dot', 
        width=3
    ),
    error_y=dict(
        type='data',
        array=gateUy2,
        visible=True,
        thickness=0.5,
        width=1.5,
        opacity=0.5,
        color='#9CEF9C'
    )
)


#Plot gamma Index with plotly
trace3 = go.Scatter(
    x = emcX2,
    y = emcY2,
    mode = 'lines', 
    name = 'eMC ', 
    line = dict(
        color=('rgba(31, 119, 180, 100)'), 
        dash='dash'
    ),
    error_y=dict(
        type='percent',
        value=2,
        visible=True,
        thickness=0.5,
        width=1.5,
        opacity=0.5, 
        color='#7CBAE6'
    )
)


    #Plot gamma Index with plotly
trace4 = go.Scatter(
    x = gateX2,
    y = gammaIndex,
    mode = 'lines', 
    name = 'Gamma index GATE', 
    line = dict(
        color = ('rgba(44, 160, 44, 100)'),
        dash='dot', 
        width=3
    )
)


    #Plot gamma Index with plotly
trace5 = go.Scatter(
    x =emcX2,
    y = gammaIndex2,
    mode = 'lines', 
    name = 'Gamma index eMC', 
    line = dict(
        color=('rgba(31, 119, 180, 100)'), 
        dash='dot',
        width=3
    )
)



print 'ok'
# Out:
# ok

# %%
val1=str(round(passRate,2))
val2=str(round(passRate2,2))
if heter =='b':
    tit_h='BONE'
if heter =='l':
    tit_h='LUNG'
if heter =='s':
    tit_h='WATER STEP'

maskgam=(emcX2 > -70) & (emcX2 < 70)

layout1= go.Layout(
    title='Dose Profile -'+ tit_h +'- '+energy+' MeV',
    titlefont=dict(size=24),
    annotations=[dict(
        x=-17,
        y=0.5,
        xref='gateX2',
        yref='gateY2',
        showarrow=False, 
        text= 'Depth:'+depth+ 'mm',
        font=dict(
        size=18)
     ),
      dict(
        x=-25,
        y=emcY2[maskgam].max()+0.5,
        xref='gateX2',
        yref='gateY2',
            showarrow=False, 
        text='WATER',
        font=dict(
        size=18),
        bordercolor='040404',
        borderwidth=1,
        borderpad=3,
        #bgcolor='97DBE4',
        #opacity=0.8
          
          
      ), 
    dict(
        x=25,
        y=emcY2[maskgam].max()+0.5,
        xref='gateX2',
        yref='gateY2',
            showarrow=False, 
        text=tit_h,
        font=dict(
        size=18),
        bordercolor='040404',
        borderwidth=1,
        borderpad=3,
        #bgcolor='97DBE4',
        #opacity=0.8
          
          
      )],
    xaxis=dict(
        range=[-100, 100],
        title='Off axis distance (mm)',
        titlefont=dict(
            size=20
        )
),      
    yaxis=dict(
        title='Relative Dose',
        titlefont=dict(
        size=20)
    )
)

layout2= go.Layout(
    title='Gamma index -'+ tit_h +'- '+energy+' MeV',
    titlefont=dict(size=24),
    annotations=[
        dict(
            x=-30,
            y=(gammaIndex2[maskgam].max()/2)+0.5,
            xref='gateX2',
            yref='gammaIndex',
            showarrow=False, 
            text='3%-3mm Gate: ' + val1 +'%',
            font=dict(
            size=18,
            color='#e91212')
     ),
        dict(
            x=-30,
            y=(gammaIndex2[maskgam].max()/2)-0.5,
            xref='gateX2',
            yref='gammaIndex',
            showarrow=False, 
            text='3%-3mm eMC: ' +  val2 +'%',
            font=dict(
            size=18,
            color='#e91212' )
     )              
    ],
    xaxis=dict(
        title='Off axis distance (mm)',
        range=[-70, 70],
        titlefont=dict(
                size=20)
    ),
    yaxis=dict(
        title='Gamma index value',
        range=[0, (gammaIndex2[maskgam].max()+0.25)],
        titlefont=dict(
                size=20)
    )

)

print 'ok'
# Out:
# ok

# %%
data1 = [trace1, trace2, trace3]
fig1= go.Figure(data=data1, layout=layout1)   

py.iplot(fig1, filename=name+'_plot', image='svg')
# Out:
# <div id="0dd923f1-bf17-406b-aca9-a8d3b9ed1b56" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("0dd923f1-bf17-406b-aca9-a8d3b9ed1b56", [{"name": "Film Measure", "mode": "lines", "y": [0.021861454235377883, 0.021800564853229284, 0.02173967547108069, 0.02167878608893209, 0.021605007854194752, 0.02123357477905576, 0.020862141703916762, 0.02049070862877777, 0.020241209942401774, 0.021337241063230396, 0.022433272184059015, 0.023529303304887814, 0.02439378987604232, 0.02363265652534767, 0.02287152317465302, 0.022110389823958364, 0.021555784728207024, 0.022036821005846037, 0.02251785728348505, 0.022998893561124063, 0.023212883177797468, 0.022409126359463898, 0.021605369541130327, 0.02080161272279676, 0.020079874099820667, 0.019604927084891144, 0.01912998006996162, 0.0186550330550321, 0.018057812901614522, 0.017162720450401174, 0.016267627999187823, 0.015372535547974474, 0.014941235721068858, 0.015440539199124512, 0.015939842677180165, 0.01643914615523582, 0.01682224475684171, 0.017011005749954733, 0.01719976674306776, 0.01738852773618078, 0.017840590455393223, 0.018662614474143455, 0.019484638492893683, 0.020306662511643914, 0.020287623284896514, 0.019270749128368455, 0.0182538749718404, 0.01723700081531234, 0.016475336356716105, 0.015969944228778468, 0.01546455210084083, 0.014959159972903112, 0.014440601943965797, 0.013910853131882298, 0.013381104319798796, 0.012851355507715295, 0.013519698222367508, 0.01504805399056238, 0.016576409758757252, 0.018104765526952123, 0.01849375727522164, 0.01819539300174934, 0.01789702872827704, 0.017598664454804742, 0.017551468997904943, 0.01763062680107592, 0.0177097846042469, 0.017788942407417876, 0.0178121440793212, 0.0178121440793212, 0.0178121440793212, 0.0178121440793212, 0.01737006154311004, 0.016779422062970867, 0.016188782582831785, 0.015598143102692705, 0.015286529007480438, 0.015049055402063718, 0.014811581796646996, 0.014574108191230273, 0.014994956095844909, 0.015549060946596013, 0.01610316579734712, 0.016657270648098226, 0.016105391085734406, 0.015392970269484193, 0.014680549453233977, 0.013968128636983764, 0.013679063201277151, 0.013429411565224467, 0.01317975992917178, 0.012930108293119054, 0.01284351973664882, 0.01276436186817658, 0.01268520399970434, 0.012606046131232097, 0.01341411759385848, 0.014223963144956255, 0.015033808696054026, 0.015821958019627318, 0.01608378789226628, 0.016345617764905247, 0.01660744763754421, 0.01692562770114235, 0.01788161118961482, 0.018837594678087283, 0.019793578166559748, 0.020472227839633216, 0.01916916754324395, 0.017866107246854685, 0.016563046950465416, 0.015438122155816575, 0.01521891593165088, 0.01499970970748518, 0.014780503483319449, 0.014918679177496352, 0.01643485681208041, 0.017951034446664474, 0.019467212081248537, 0.020449840213418616, 0.019810488726268626, 0.01917113723911864, 0.01853178575196865, 0.01805791293886579, 0.01799093320400467, 0.01792395346914355, 0.01785697373428243, 0.017210064634769633, 0.015389433659908127, 0.013568802685046621, 0.011748171710185117, 0.010922691809735345, 0.011775143159816327, 0.012627594509897172, 0.013480045859978019, 0.014075505852425686, 0.014306890295596432, 0.014538274738767178, 0.014769659181937924, 0.015095319426058542, 0.01553373223605875, 0.015972145046058955, 0.016410557856059164, 0.016561496232069987, 0.016421447753308747, 0.0162813992745475, 0.016141350795786262, 0.01611935591997853, 0.016198513788450764, 0.016277671656923, 0.01635682952539523, 0.016022685256948655, 0.015389422570375892, 0.014756159883803126, 0.014122897197230361, 0.013353348470414493, 0.012500879117636554, 0.011648409764858618, 0.010795940412080679, 0.010779533586774139, 0.011187501062746538, 0.011595468538718937, 0.012003436014691338, 0.012548753250251305, 0.013151570864001452, 0.0137543884777516, 0.014357206091501743, 0.014841842893666685 ...
# <script>function downloadimage(format, height, width, filename) {var p = document.getElementById('0dd923f1-bf17-406b-aca9-a8d3b9ed1b56');Plotly.downloadImage(p, {format: format, height: height, width: width, filename: filename});};if(document.readyState == 'complete') {{downloadimage('svg', 600, 800, 'stair6e30_good_plot');}}</script>

# %%
data2= [trace4, trace5]
fig2= go.Figure(data=data2, layout=layout2)
py.iplot(fig2, filename=name+'_gamma')
# Out:
# <div id="726b386c-80c4-4272-a0d6-026651ba2147" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("726b386c-80c4-4272-a0d6-026651ba2147", [{"name": "Gamma index GATE", "mode": "lines", "y": [0.8179091052246265, 0.7922405580368266, 0.7671343678978254, 0.7426475706846589, 0.7188434664793171, 0.6957921267005809, 0.6735708404313342, 0.6522644477530346, 0.6319654909471764, 0.6127740961528846, 0.5947974809178366, 0.5781489712165581, 0.562946411085163, 0.5493098668428457, 0.5373585740364504, 0.5272071543448652, 0.5189612406689678, 0.5127127795006466, 0.5085354052887797, 0.5060557935024796, 0.4971280716299028, 0.48578447742046044, 0.4765358662909952, 0.46786501423649723, 0.46086082800038936, 0.4561447251943042, 0.4537880498191487, 0.453827560085812, 0.45626263349841945, 0.4610553149667409, 0.46813319951691584, 0.4773946562536121, 0.48871556088154244, 0.4994021629779663, 0.49902472656111885, 0.4898666073913917, 0.47080644998875776, 0.44752749947198656, 0.4242270364434511, 0.4012186731721437, 0.37969006472797506, 0.3586553580304179, 0.33871975593415105, 0.3209656113470923, 0.3045930520547301, 0.2890485487654848, 0.27660738080899067, 0.2677025701851717, 0.2626939901113901, 0.2618053517189817, 0.26507809288569295, 0.2723622438193153, 0.2833486046901025, 0.29762747704559056, 0.31157889845910236, 0.3250091343621416, 0.3297122843828269, 0.3344304983975494, 0.3278534897828996, 0.3094170711503254, 0.29110538149914755, 0.27404599392057677, 0.2582380864307142, 0.24225948404739914, 0.22632774563518343, 0.20979061901258214, 0.1933714481822685, 0.18025970376395586, 0.1725571182187704, 0.17099623303687303, 0.17574077158010581, 0.18630963554330052, 0.20178973267963918, 0.22115213440412287, 0.2416050927044814, 0.26267339137676393, 0.286012158258939, 0.3111108375232826, 0.33625091244337363, 0.3399874843694787, 0.3437490039513061, 0.3333520508183059, 0.3149432530223797, 0.29905768781749636, 0.2861159447497724, 0.27479445243896594, 0.2652312413266771, 0.25634711115202213, 0.24747109109794554, 0.23860408625032264, 0.23372215136171565, 0.23345398535434495, 0.23781519652323493, 0.2465602508431219, 0.24334276808017924, 0.22833539048134183, 0.21734530934550006, 0.2067523264093412, 0.19743547926401145, 0.18812441595665202, 0.1788200399735413, 0.17367087595741615, 0.1699119887576669, 0.16646086081551853, 0.1629119820769965, 0.15975529783176154, 0.16335384909888448, 0.17328730015374516, 0.1885571009608866, 0.2079912397194184, 0.23037299498312105, 0.2512749455748695, 0.2730359645900282, 0.29275637602030385, 0.3013735486948696, 0.28386103267271273, 0.2683739333744735, 0.25622906530836936, 0.24756672756451964, 0.23890734786139262, 0.23025125994069667, 0.22252393154935907, 0.21852218523532696, 0.21930424229392748, 0.2224690124198866, 0.2285404022826211, 0.23907473726574097, 0.25351628164009965, 0.2712416646633035, 0.26398287761061995, 0.2331297045063062, 0.20297713937675976, 0.17389002165364714, 0.14650433675013722, 0.12197156339593163, 0.09848308978014284, 0.07505588503397255, 0.06128305898517596, 0.06376206782787584, 0.0810145036616972, 0.10327165530511029, 0.12436206595531712, 0.1450941804628865, 0.16641363725306457, 0.1724621668690744, 0.17852957977555042, 0.18763534031871748, 0.19708584232303497, 0.20962069093192612, 0.21490728983583576, 0.20755452245925535, 0.20392229492475608, 0.20102931458509307, 0.2015589019356561, 0.18110754352993907, 0.16011193839624896, 0.1366389713868962, 0.11360464734394109, 0.08772529848895572, 0.0648464706111061, 0.03933530365711621, 0.018169541238202545, 0.0149601004434481, 0.019742918268606233, 0.0335825912947112, 0.05057294381102886, 0.06840525889650544, 0.0907825981846269, 0.11066945255493084, 0.1332624219961185, 0.15630373238724393, 0.17789149245105662, 0.2002787921268703, 0.21981407137523484, 0.23844255894065738, 0.2572458484733487, 0.25123233116 ...
